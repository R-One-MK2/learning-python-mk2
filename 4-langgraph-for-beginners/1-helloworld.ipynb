# %%
from typing import TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    message: str


def greeting_node(state: AgentState) -> StateGraph:
    state["message"] = "Hey" + state["message"] + ", Hows your day going?"
    return state
